# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/CodeData/Code
# Out:
# /content/drive/MyDrive/CodeData/Code

# %%
# %%writefile Python_ipynb_to_py.py

print('test')
# Out:
# Writing Python_ipynb_to_py.py
