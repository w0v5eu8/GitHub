# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Git Setting (Cloning)

# %%
cd /content/drive/MyDrive/CodeData
# Out:
# /content/drive/MyDrive/CodeData

# %%
# !git clone 'https://w0v5eu8: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@github.com/w0v5eu8/Examples.git' 'GitHub_Examples'
# Out:
# Cloning into 'GitHub_Examples'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 589 bytes | 18.00 KiB/s, done.

# %% [markdown]
# # Git Command

# %%
cd /content/drive/MyDrive/CodeData/GitHub_Examples
# Out:
# /content/drive/MyDrive/CodeData/GitHub_Examples

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# Push
# after source files update,
# !git add .
# !git commit -m 'Commit'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git pull

# %%
# if push is not working
# !git remote set-url origin https://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@github.com/w0v5eu8/Examples.git
