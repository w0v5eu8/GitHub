# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Code/GitHub
# Out:
# /content/drive/MyDrive/CodeData/Code/GitHub_Examples

# %%
# %%writefile Jupyter_Cell_to_PY.py

print('test')
# Out:
# Writing JupyterNotebookCelltoPythonFileTest.py
