# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Generating SSH Key

# %%
# !ssh-keygen
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:EubwArMAx1Z4VJv2uShGjDs+ZqxgbCdcIojc4qdodYU root@e701c8314bb2
# The key's randomart image is:
# +---[RSA 3072]----+
# |...+o..          |
# |..+ .  o         |
# |..o.. B          |
# |+..* E + .       |
# |++oo+ = S        |
# |= ++ o o .       |
# |.O+o+ . .        |
# |=oXo .           |
# |+=..             |
# +----[SHA256]-----+

# %%
cd ~/.ssh/
# Out:
# /root/.ssh

# %%
# !ls
# Out:
# id_rsa	id_rsa.pub

# %%
# !cat id_rsa.pub
# Out:
# ssh-rsa ... root@e701c8314bb2

# %%
# !cp ~/.ssh/id_rsa /content/drive/MyDrive/CodeData/SSH

# %%
# !cp ~/.ssh/id_rsa.pub /content/drive/MyDrive/CodeData/SSH

# %% [markdown]
# 이후 GitHub에 공개키 등록하기

# %% [markdown]
# # SSH Setting

# %%
#!mkdir -p ~/.ssh/
#!cp /content/drive/MyDrive/CodeData/SSH/id_rsa ~/.ssh/
#!cp /content/drive/MyDrive/CodeData/SSH/id_rsa.pub ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-babeld-756a9a22
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# #Git Cloning

# %%
cd /content/drive/MyDrive/CodeData
# Out:
# /content/drive/MyDrive/CodeData

# %%
# !git clone git@github.com:w0v5eu8/GitHub.git
# Out:
# Cloning into 'GitHub'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 118 (delta 21), reused 113 (delta 19), pack-reused 0
# Receiving objects: 100% (118/118), 11.26 MiB | 10.04 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
