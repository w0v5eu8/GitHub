# %% [markdown]
# # 1. 데이터 로드

# %%
# !pip install backtrader
# !pip install backtesting
# Out:
# Collecting backtrader
#   Downloading backtrader-1.9.76.123-py2.py3-none-any.whl (410 kB)
#      |████████████████████████████████| 410 kB 5.4 MB/s
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.76.123
# Collecting backtesting
#   Downloading Backtesting-0.3.3.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 4.7 MB/s
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (1.21.5)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (1.3.5)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from backtesting) (2.3.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (21.3)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (5.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (3.13)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (2.8.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.4.0->backtesting) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=1.4.0->backtesting) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=1.4.0->backtesting) (1.15.0)
# Building wheels for collected packages: backtesting
#   Building wheel for backtesting (setup.py) ... done
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173822 sha256=687313d2c1a3483cfc412cf11e9bf18fc8235c44039d910ebb9ff956c0f50415
#   Stored in directory: /root/.cache/pip/wheels/48/1d/ea/65dacebc37da7655d8a1fd0f315ac39d102e31d6545237a1c6
# Successfully built backtesting
# Installing collected packages: backtesting
# Successfully installed backtesting-0.3.3

# %%
import numpy as np
from google.colab import drive
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn import metrics
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout
from keras.layers import LSTM, SimpleRNN, GRU, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Concatenate
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import backtrader as bt
from backtrader.feeds import PandasData
import backtrader.indicators as btind

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. 데이터 전처리

# %%
def datasplit(df, Y_colname, X_colname): #데이터 분리 함수
  df_train = df.loc[0 : round(len(df) * 0.75)] 
  df_test = df.loc[round(len(df) * 0.75) + 1 : ]
  Y_train = df_train[Y_colname]
  X_train = df_train[X_colname]
  Y_test = df_test[Y_colname]
  X_test = df_test[X_colname]
  return X_train, X_test, Y_train, Y_test

# %%
def get_preprocessed_data(data, seq_length=30):
  #최신 데이터가 뒤로 오도록 정렬
  data = data.sort_values(by=['TRD_DD'])
  data.set_index('TRD_DD',drop=True,inplace=True)
  data.reset_index('TRD_DD',drop=False,inplace=True)

  #X/Y데이터로 분리
  Y_colname = ['TREND'] #종속변수
  X_remove = ['TRD_DD']
  X_colname = [x for x in data.columns if x not in Y_colname + X_remove] #입력변수들

  #train/test로 분리
  X_train, X_test, Y_train, Y_test = datasplit(data, Y_colname, X_colname)

  #array로 변환
  X_train_arr = X_train.values
  Y_train_arr = Y_train.values
  X_test_arr = X_test.values
  Y_test_arr = Y_test.values

  #sequence 생성
  X_train, Y_train = [], []
  for index in range(len(X_train_arr) - seq_length): #sequence개의 데이터만큼 차분데이터 분석에 사용하므로, 총 데이터 개수 - sequence개수가 전체 데이터의 길이 --> 총길이만큼 돌리는 것이므로, 기존 차원을 뜻하는 (row, column) 꼴에는 변함 없음 --> 2차원 데이터
    X_train.append(np.array(X_train_arr[index:index + seq_length])) #X_train 데이터 --> index가 sequence인 1차원 데이터 생성 --> sequence를 뜻하는 차원 생성
    Y_train.append(np.ravel(Y_train_arr[index + seq_length:index + seq_length + 1])) #Y_train 데이터 --> index가 sequence인 1차원 데이터 생성 --> 그러나 ravel() 로 차원축소 --> sequence차원 생성되지 않음.
  X_train, Y_train = np.array(X_train), np.array(Y_train) #array로 저장되어있는 리스트를 array로 변환해서 저장
  X_test, Y_test = [], [] #동일한 과정 test데이터셋에도 적용
  for index in range(len(X_test_arr) - seq_length):
    X_test.append(np.array(X_test_arr[index:index + seq_length])) 
    Y_test.append(np.ravel(Y_test_arr[index + seq_length:index + seq_length + 1]))
  X_test, Y_test = np.array(X_test), np.array(Y_test)

  return X_train, Y_train, X_test, Y_test

# %% [markdown]
# # 3. 모델링

# %%
batch_size = 60 #미니 배치 내 데이터 수
epoch = 80 #돌릴 횟수

# %%
def Inception_sim_model(): 
  input_tensor = Input(shape=(X_train.shape[1], X_train.shape[2])) # 30 * 5 (sequence * channel)

  f10_layer = Conv1D(256, 1, 1, activation='relu')(input_tensor) # 30 * 256
  f10_layer_1 = Conv1D(128, 10, 1, activation='relu')(f10_layer) # 21 * 128 
  f10_layer_2 = Conv1D(64, 6, 1, activation='relu')(f10_layer_1) # 16 * 64
  f10_layer_3 = Conv1D(32, 3, 1, activation='relu')(f10_layer_2) # 14 * 32

  f15_layer = Conv1D(256, 1, 1, activation='relu')(input_tensor) # 30 * 256
  f15_layer_1 = Conv1D(128, 15, 1, activation='relu')(f15_layer) # 16 * 128
  f15_layer_2 = Conv1D(64, 3, 1, activation='relu')(f15_layer_1) # 14 * 64

  f7_layer = Conv1D(256, 1, 1, activation='relu')(input_tensor) # 30 * 256
  f7_layer_1 = Conv1D(128, 7, 1, activation='relu')(f7_layer) # 24 * 128
  f7_layer_2 = Conv1D(64, 7, 1, activation='relu')(f7_layer_1) # 18 * 64
  f7_layer_3 = Conv1D(32, 5, 1, activation='relu')(f7_layer_2) # 14 * 32

  f2_pooling = MaxPooling1D(2)(input_tensor) # 15 * 5
  f2_layer = Conv1D(128, 2, 1, activation='relu')(f2_pooling) # 14 * 128

  concat_layer = Concatenate(axis=-1)([f10_layer_3, f15_layer_2, f7_layer_3, f2_layer]) # 14 * 256

  gru_layer = GRU(512, return_sequences=True, dropout=0.2, activation='relu')(concat_layer) # 14 * 512
  gru_layer_1 = GRU(256, return_sequences=True, dropout=0.2, activation='relu')(gru_layer) # 14 * 256
  gru_layer_2 = GRU(64, return_sequences=False, dropout=0.2, activation='relu')(gru_layer_1) # 64
  output = Dense(1)(gru_layer_2) # 1

  model = Model(inputs=input_tensor, outputs=output)
  return model

# %%
def GRU_model():
  input_tensor = Input(shape=(X_train.shape[1], X_train.shape[2])) # 17 * 5
  x = GRU(128, return_sequences=True, dropout=0.2, activation='relu')(input_tensor) # 17 * 128
  x = GRU(256, return_sequences=True, dropout=0.2, activation='relu')(x) # 17 * 256
  x = GRU(64, return_sequences=False, dropout=0.2, activation='relu')(x) # 64
  output = Dense(1)(x) # 1
  model = Model(inputs=input_tensor, outputs=output)
  return model

# %%
def LSTM_model():
  input_tensor = Input(shape=(X_train.shape[1], X_train.shape[2])) # 17 * 5
  x = LSTM(128, return_sequences=True, dropout=0.2, activation='relu')(input_tensor) # 17 * 128
  x = LSTM(256, return_sequences=True, dropout=0.2, activation='relu')(x) # 17 * 256
  x = LSTM(64, return_sequences=False, dropout=0.2, activation='relu')(x) # 64
  output = Dense(1)(x) # 1
  model = Model(inputs=input_tensor, outputs=output)
  return model

# %%
def train_model(X_train, Y_train, X_test, Y_test, modelname='Inception_sim_model'): #모델 학습 함수
  if modelname == 'Inception_sim_model':
    model = Inception_sim_model()
  elif modelname == 'CNN_GRU_model':
    model = CNN_GRU_model()
  elif modelname == 'LSTM_model':
    model = LSTM_model()
  elif modelname == 'GRU_model':
    model = GRU_model() 

  model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
  rlr_cb = ReduceLROnPlateau(patience=5, mode='min')
  ely_cb = EarlyStopping(patience=10, mode='min') 
  hist = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epoch, verbose=1, validation_split=0.15, callbacks=([rlr_cb, ely_cb]))

  return model, hist

# %% [markdown]
# # 4. backtest

# %%
class PandasData_Signal(PandasData):

  lines = ('signal',)

  # add the parameter to the parameters inherited from the base class

  params = (('signal', 6),)

class MLSignal(bt.SignalStrategy):

    def log(self, txt, dt=None):

        ''' Logging function fot this strategy'''

        dt = dt or self.datas[0].datetime.date(0)

        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        self.dataclose = self.datas[0].close
        self.signal = self.datas[0].signal
        self.order = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                    order.executed.value,
                    order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                (trade.pnl, trade.pnlcomm))
        
    def next(self):
        #Check if we are in the market 
        if not self.position :            
            if self.signal[0] == -1:
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                size = int(self.broker.getcash() / self.dataclose[0])
                #Keep track of the created order to avoid a 2nd order
                self.order = self.buy(size = size)
                
        else:           
            #Already in the market...we might sell                     
            if self.signal[0] == 1:
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.order = self.sell()

# %% [markdown]
# # 실행

# %%
mktcap_top = ['KR7005930003', 'KR7000660001', 'KR7035420009', 'KR7207940008', 'KR7005931001', 'KR7035720002', 'KR7006400006', 'KR7005380001', 'KR7051910008', 'KR7000270009'] # 데이터 로드

# %%
# 실행 코드
final_df = pd.DataFrame([], columns = ['full_code', 'train', 'test', 'MDD', 'CAGR', 'profit'])

for i in range(len(mktcap_top)):
  mktcap_data = pd.read_csv('/content/drive/MyDrive/data/mktcap10/{}.csv'.format(mktcap_top[i]))
  mktcap_data['TREND'] = mktcap_data['TREND'].fillna(0)

  X_train, Y_train, X_test, Y_test = get_preprocessed_data(mktcap_data, 30)

  optimum_df = pd.DataFrame([], columns = ['train', 'test', 'MDD', 'CAGR', 'profit'])
  
  headers = ['train', 'test', 'MDD', 'CAGR', 'profit']
  profit_df = pd.DataFrame([], columns = headers)

  model, hist = train_model(X_train, Y_train, X_test, Y_test, modelname='GRU_model')  # modelname='LSTM_model' 로 수정시 LSTM모델, 'CNN_GRU_model' 로 수정시 CNN_GRU 모델로 바뀜

  past = model.predict(X_test)

  Y_train_pred = model.predict(X_train)
  Y_test_pred = model.predict(X_test)


  a = list(X_train.shape)
  b = list(X_test.shape)
  test_data = mktcap_data.iloc[a[0]:]

  test_score = test_data.copy()
  test_score.reset_index(drop=True, inplace=True)
  imsi_df = pd.DataFrame(Y_test_pred, columns=['pred'])
  test_score = pd.concat([test_score, imsi_df], axis=1)
  test_score.fillna(0, inplace=True)
  test_score = test_score[['TRD_DD', 'pred']]
  test_score = test_score.reset_index()
  test_score = test_score.drop(['index'], axis = 1)

  for j in range(len(test_score)):
    if test_score['pred'][j] < -0.5:
      test_score['pred'][j] = -1
    elif test_score['pred'][j] > 0.5:
      test_score['pred'][j] = 1
    else:
      test_score['pred'][j] = 0
  print('\n', test_score.value_counts(['pred']), '--------------------------------')

  json_df = pd.read_csv('/content/drive/MyDrive/data/raw_data/{}.csv'.format(mktcap_top[i])) # 첫번째 키값으로 데이터프레임 변환
  json_df = json_df[['TRD_DD', 'TDD_OPNPRC', 'TDD_HGPRC', 'TDD_LWPRC', 'TDD_CLSPRC', 'ACC_TRDVOL']]
  json_df = json_df.sort_values(by=['TRD_DD'])
  json_df.reset_index(drop=True,inplace=True)

  df_end = json_df.index[json_df['TRD_DD'] == '2021/12/30'][0]
  raw = json_df.iloc[a[0]:df_end+1]
  raw.reset_index(drop = True, inplace = True)
  raw['TRD_DD'] = pd.to_datetime(raw['TRD_DD'])
                  
  final = pd.merge(raw, test_score, left_index = True, right_index = True).drop(columns='TRD_DD_y')
  final = final.rename(columns={'TRD_DD_x': 'TRD_DD'})
  final['TDD_OPNPRC'] = final['TDD_OPNPRC'].str.replace(',','').astype('float')
  final['TDD_HGPRC'] = final['TDD_HGPRC'].str.replace(',','').astype('float')
  final['TDD_LWPRC'] = final['TDD_LWPRC'].str.replace(',','').astype('float')
  final['TDD_CLSPRC'] = final['TDD_CLSPRC'].str.replace(',','').astype('float')
  final['ACC_TRDVOL'] = final['ACC_TRDVOL'].str.replace(',','').astype('float')
  final = final.astype({'pred':'int'})

  # 세레브로 (벡트레이더 엔진) 설정

  # 세레브로 가져오기
  cerebro = bt.Cerebro()

  # 데이터 가져오기
  data = PandasData_Signal(dataname = final,
                                  datetime = 0,
                                  open = 1,
                                  high = 2,
                                  low = 3,
                                  close = 4,
                                  volume = 5,
                                  openinterest = -1,
                                  signal = 6,
                                  )

  # 데이터 추가하기
  cerebro.adddata(data)

  # 전략 추가하기
  cerebro.addstrategy(MLSignal)

  # 브로커 설정
  cerebro.broker.setcash(10000000)

  # 매매 단위 설정
  #cerebro.addsizer(bt.sizers.SizerFix, stake = 30) #한번에 30주 설정.

  # 3. 세레브로 실행하기

  # 초기 투자금 가져오기
  init_cash = cerebro.broker.getvalue()

  # 평가지표 추가
  cerebro.addanalyzer(bt.analyzers.SharpeRatio, riskfreerate=0.0)
  cerebro.addanalyzer(bt.analyzers.Returns)
  cerebro.addanalyzer(bt.analyzers.DrawDown)

  # 세레브로 실행하기
  results = cerebro.run()

  # 최종 금액 가져오기
  final_cash = cerebro.broker.getvalue()

  analyzers = results[0].analyzers
  mdd = analyzers.drawdown.get_analysis()['max']['drawdown']
  cagr = analyzers.returns.get_analysis()['rnorm100']
  # sharp = analyzers.sharperatio.get_analysis()['sharperatio']
  print(f"mdd : {mdd:.2f}, cagr: {cagr:.2f}")


  profit = float(final_cash - init_cash)/float(init_cash) * 100.
  print("최종금액 : ", final_cash, "원")
  print("수익률 : ", profit, "%")
  print("\n")

  profit_list = [a[0], b[0], mdd, cagr, profit]
  profit_df = profit_df.append(pd.Series(profit_list, index = headers), ignore_index = True)

  max_profit = profit_df[profit_df['profit'] == profit_df['profit'].max()].reset_index(drop = True)


  num_max_profit = pd.concat([max_profit], axis = 1)
  optimum_df = pd.concat([optimum_df, num_max_profit], axis = 0).reset_index(drop = True)
  # print(optimum_df)

  op_list = optimum_df.iloc[0].tolist()
  op_list.insert(0, mktcap_top[i])
  print(op_list)

  final_df = final_df.append(pd.Series(op_list, index=final_df.columns), ignore_index=True)

print(final_df)
# Out:
# WARNING:tensorflow:Layer gru_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 72/72 [==============================] - 33s 378ms/step - loss: 0.3160 - accuracy: 0.0110 - val_loss: 0.2723 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 2/80
# 72/72 [==============================] - 27s 380ms/step - loss: 0.2830 - accuracy: 0.0112 - val_loss: 0.2785 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 3/80
# 72/72 [==============================] - 31s 437ms/step - loss: 0.2788 - accuracy: 0.0112 - val_loss: 0.2579 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 4/80
# 72/72 [==============================] - 30s 424ms/step - loss: 0.2692 - accuracy: 0.0114 - val_loss: 0.2605 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 5/80
# 72/72 [==============================] - 27s 371ms/step - loss: 0.2676 - accuracy: 0.0121 - val_loss: 0.2582 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 6/80
# 72/72 [==============================] - 27s 375ms/step - loss: 0.2648 - accuracy: 0.0110 - val_loss: 0.2732 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 7/80
# 72/72 [==============================] - 27s 367ms/step - loss: 0.2596 - accuracy: 0.0119 - val_loss: 0.2600 - val_accuracy: 0.0106 - lr: 0.0010
# Epoch 8/80
# 72/72 [==============================] - 27s 375ms/step - loss: 0.2534 - accuracy: 0.0126 - val_loss: 0.2633 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 9/80
# 72/72 [==============================] - 26s 363ms/step - loss: 0.2491 - accuracy: 0.0126 - val_loss: 0.2592 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 10/80
# 72/72 [==============================] - 26s 368ms/step - loss: 0.2439 - accuracy: 0.0140 - val_loss: 0.2583 - val_accuracy: 0.0092 - lr: 1.0000e-04
# Epoch 11/80
# 72/72 [==============================] - 26s 366ms/step - loss: 0.2437 - accuracy: 0.0126 - val_loss: 0.2573 - val_accuracy: 0.0106 - lr: 1.0000e-04
# Epoch 12/80
# 72/72 [==============================] - 27s 371ms/step - loss: 0.2391 - accuracy: 0.0149 - val_loss: 0.2570 - val_accuracy: 0.0106 - lr: 1.0000e-04
# Epoch 13/80
# 72/72 [==============================] - 27s 374ms/step - loss: 0.2420 - accuracy: 0.0142 - val_loss: 0.2581 - val_accuracy: 0.0106 - lr: 1.0000e-04
# Epoch 14/80
# 72/72 [==============================] - 28s 383ms/step - loss: 0.2441 - accuracy: 0.0133 - val_loss: 0.2539 - val_accuracy: 0.0092 - lr: 1.0000e-04
# Epoch 15/80
# 72/72 [==============================] - 29s 401ms/step - loss: 0.2434 - accuracy: 0.0140 - val_loss: 0.2568 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 16/80
# 72/72 [==============================] - 28s 391ms/step - loss: 0.2410 - accuracy: 0.0140 - val_loss: 0.2555 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 17/80
# 72/72 [==============================] - 28s 392ms/step - loss: 0.2392 - accuracy: 0.0154 - val_loss: 0.2580 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 18/80
# 72/72 [==============================] - 28s 391ms/step - loss: 0.2382 - accuracy: 0.0145 - val_loss: 0.2571 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 19/80
# 72/72 [==============================] - 28s 392ms/step - loss: 0.2377 - accuracy: 0.0152 - val_loss: 0.2582 - val_accuracy: 0.0119 - lr: 1.0000e-04
# Epoch 20/80
# 72/72 [==============================] - 28s 395ms/step - loss: 0.2364 - accuracy: 0.0159 - val_loss: 0.2578 - val_accuracy: 0.0119 - lr: 1.0000e-05
# Epoch 21/80
# 72/72 [==============================] - 28s 395ms/step - loss: 0.2346 - accuracy: 0.0149 - val_loss: 0.2574 - val_accuracy: 0.0119 - lr: 1.0000e-05
# Epoch 22/80
# 72/72 [==============================] - 29s 399ms/step - loss: 0.2363 - accuracy: 0.0156 - val_loss: 0.2570 - val_accuracy: 0.0119 - lr: 1.0000e-05
# Epoch 23/80
# 72/72 [==============================] - 28s 395ms/step - loss: 0.2355 - accuracy: 0.0152 - val_loss: 0.2572 - val_accuracy: 0.0119 - lr: 1.0000e-05
# Epoch 24/80
# 72/72 [==============================] - 29s 399ms/step - loss: 0.2370 - accuracy: 0.0154 - val_loss: 0.2573 - val_accuracy: 0.0106 - lr: 1.0000e-05
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  pred
#  0.0    1582
#  1.0     101
# -1.0      36
# dtype: int64 --------------------------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2015-10-08, BUY CREATE, 1270000.00
# 2015-10-12, BUY EXECUTED, Price: 1260000.00, Cost: 8820000.00, Comm 0.00
# 2016-05-26, SELL CREATE, 1296000.00
# 2016-05-27, SELL EXECUTED, Price: 1300000.00, Cost: 1260000.00, Comm 0.00
# 2016-05-27, SELL CREATE, 1282000.00
# 2016-05-30, SELL EXECUTED, Price: 1297000.00, Cost: 1260000.00, Comm 0.00
# 2016-05-30, SELL CREATE, 1280000.00
# 2016-05-31, SELL EXECUTED, Price: 1280000.00, Cost: 1260000.00, Comm 0.00
# 2016-05-31, SELL CREATE, 1292000.00
# 2016-06-01, SELL EXECUTED, Price: 1298000.00, Cost: 1260000.00, Comm 0.00
# 2016-06-01, SELL CREATE, 1333000.00
# 2016-06-02, SELL EXECUTED, Price: 1350000.00, Cost: 1260000.00, Comm 0.00
# 2017-04-24, SELL CREATE, 2062000.00
# 2017-04-25, SELL EXECUTED, Price: 2073000.00, Cost: 1260000.00, Comm 0.00
# 2017-04-25, SELL CREATE, 2135000.00
# 2017-04-26, SELL EXECUTED, Price: 2135000.00, Cost: 1260000.00, Comm 0.00
# 2017-04-26, OPERATION PROFIT, GROSS 1913000.00, NET 1913000.00
# 2017-05-17, BUY CREATE, 2317000.00
# 2017-05-18, BUY EXECUTED, Price: 2287000.00, Cost: 11435000.00, Comm 0.00
# 2017-08-08, SELL CREATE, 2386000.00
# 2017-08-09, SELL EXECUTED, Price: 2370000.00, Cost: 2287000.00, Comm 0.00
# 2017-08-09, SELL CREATE, 2314000.00
# 2017-08-10, SELL EXECUTED, Price: 2310000.00, Cost: 2287000.00, Comm 0.00
# 2017-08-10, SELL CREATE, 2295000.00
# 2017-08-11, SELL EXECUTED, Price: 2256000.00, Cost: 2287000.00, Comm 0.00
# 2017-08-11, SELL CREATE, 2231000.00
# 2017-08-14, SELL EXECUTED, Price: 2256000.00, Cost: 2287000.00, Comm 0.00
# 2017-08-14, SELL CREATE, 2250000.00
# 2017-08-16, SELL EXECUTED, Price: 2311000.00, Cost: 2287000.00, Comm 0.00
# 2017-08-16, OPERATION PROFIT, GROSS 68000.00, NET 68000.00
# 2018-07-16, BUY CREATE, 46050.00
# 2018-07-17, Order Canceled/Margin/Rejected
# 2018-07-19, BUY CREATE, 46900.00
# 2018-07-20, Order Canceled/Margin/Rejected
# 2018-07-20, BUY CREATE, 47450.00
# 2018-07-23, BUY EXECUTED, Price: 47100.00, Cost: 11869200.00, Comm 0.00
# 2019-01-15, SELL CREATE, 41100.00
# 2019-01-16, SELL EXECUTED, Price: 41150.00, Cost: 47100.00, Comm 0.00
# 2019-01-16, SELL CREATE, 41450.00
# 2019-01-17, SELL EXECUTED, Price: 41700.00, Cost: 47100.00, Comm 0.00
# 2019-01-17, SELL CREATE, 41950.00
# 2019-01-18, SELL EXECUTED, Price: 42000.00, Cost: 47100.00, Comm 0.00
# 2019-04-18, SELL CREATE, 45600.00
# 2019-04-19, SELL EXECUTED, Price: 45750.00, Cost: 47100.00, Comm 0.00
# 2019-04-19, SELL CREATE, 45300.00
# 2019-04-22, SELL EXECUTED, Price: 45400.00, Cost: 47100.00, Comm 0.00
# 2019-04-22, SELL CREATE, 45350.00
# 2019-04-23, SELL EXECUTED, Price: 45050.00, Cost: 47100.00, Comm 0.00
# 2019-04-23, SELL CREATE, 45200.00
# 2019-04-24, SELL EXECUTED, Price: 45400.00, Cost: 47100.00, Comm 0.00
# 2019-04-24, SELL CREATE, 44750.00
# 2019-04-25, SELL EXECUTED, Price: 44250.00, Cost: 47100.00, Comm 0.00
# 2019-04-29, SELL CREATE, 46150.00
# 2019-04-30, SELL EXECUTED, Price: 46000.00, Cost: 47100.00, Comm 0.00
# 2019-04-30, SELL CREATE, 45850.00
# 2019-05-02, SELL EXECUTED, Price: 45500.00, Cost: 47100.00, Comm 0.00
# 2019-05-02, SELL CREATE, 45900.00
# 2019-05-03, SELL EXECUTED, Price: 45900.00, Cost: 47100.00, Comm 0.00
# 2019-08-20, SELL CREATE, 44450.00
# 2019-08-21, SELL EXECUTED, Price: 44350.00, Cost: 47100.00, Comm 0.00
# 2019-08-21, SELL CREATE, 44500.00
# 2019-08-22, SELL EXECUTED, Price: 44500.00, Cost: 47100.00, Comm 0.00
# 2020-07-09, SELL CREATE, 52800.00
# 2020-07-10, SELL EXECUTED, Price: 53100.00, Cost: 47100.00, Comm 0.00
# 2020-07-10, SELL CREATE, 52700.00
# 2020-07-13, SELL EXECUTED, Price: 53300.00, Cost: 47100.00, Comm 0.00
# 2020-07-13, SELL CREATE, 53400.00
# 2020-07-14, SELL EXECUTED, Price: 53700.00, Cost: 47100.00, Comm 0.00
# 2020-07-14, SELL CREATE, 53800.00
# 2020-07-15, SELL EXECUTED, Price: 54400.00, Cost: 47100.00, Comm 0.00
# 2020-07-15, SELL CREATE, 54700.00
# 2020-07-16, SELL EXECUTED, Price: 54800.00, Cost: 47100.00, Comm 0.00
# 2020-07-16, SELL CREATE, 53800.00
# 2020-07-17, SELL EXECUTED, Price: 54200.00, Cost: 47100.00, Comm 0.00
# 2020-10-05, SELL CREATE, 58700.00
# 2020-10-06, SELL EXECUTED, Price: 59400.00, Cost: 47100.00, Comm 0.00
# 2020-10-06, SELL CREATE, 59000.00
# 2020-10-07, SELL EXECUTED, Price: 58700.00, Cost: 47100.00, Comm 0.00
# 2020-10-07, SELL CREATE, 59900.00
# 2020-10-08, SELL EXECUTED, Price: 60500.00, Cost: 47100.00, Comm 0.00
# 2020-10-13, SELL CREATE, 60900.00
# 2020-10-14, SELL EXECUTED, Price: 61000.00, Cost: 47100.00, Comm 0.00
# 2020-10-14, SELL CREATE, 60900.00
# 2020-10-15, SELL EXECUTED, Price: 60700.00, Cost: 47100.00, Comm 0.00
# 2021-01-07, SELL CREATE, 82900.00
# 2021-01-08, SELL EXECUTED, Price: 83300.00, Cost: 47100.00, Comm 0.00
# 2021-01-08, SELL CREATE, 88800.00
# 2021-01-11, SELL EXECUTED, Price: 90000.00, Cost: 47100.00, Comm 0.00
# 2021-06-28, SELL CREATE, 81900.00
# 2021-06-29, SELL EXECUTED, Price: 81900.00, Cost: 47100.00, Comm 0.00
# 2021-06-29, SELL CREATE, 81000.00
# 2021-06-30, SELL EXECUTED, Price: 81100.00, Cost: 47100.00, Comm 0.00
# mdd : 30.48, cagr: 10.07
# 최종금액 :  19188050.0 원
# 수익률 :  91.8805 %
#
#
# ['KR7005930003', 5043.0, 1659.0, 30.483228488016227, 10.068001683754233, 91.8805]
# WARNING:tensorflow:Layer gru_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 67/67 [==============================] - 33s 408ms/step - loss: 0.3001 - accuracy: 0.0111 - val_loss: 0.3247 - val_accuracy: 0.0100 - lr: 0.0010
# Epoch 2/80
# 67/67 [==============================] - 26s 392ms/step - loss: 0.2700 - accuracy: 0.0138 - val_loss: 0.3118 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 3/80
# 67/67 [==============================] - 26s 394ms/step - loss: 0.2613 - accuracy: 0.0164 - val_loss: 0.3154 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 4/80
# 67/67 [==============================] - 27s 403ms/step - loss: 0.2573 - accuracy: 0.0153 - val_loss: 0.2948 - val_accuracy: 0.0100 - lr: 0.0010
# Epoch 5/80
# 67/67 [==============================] - 26s 394ms/step - loss: 0.2556 - accuracy: 0.0146 - val_loss: 0.3004 - val_accuracy: 0.0100 - lr: 0.0010
# Epoch 6/80
# 67/67 [==============================] - 26s 394ms/step - loss: 0.2544 - accuracy: 0.0151 - val_loss: 0.3159 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 7/80
# 67/67 [==============================] - 27s 399ms/step - loss: 0.2529 - accuracy: 0.0169 - val_loss: 0.2985 - val_accuracy: 0.0142 - lr: 0.0010
# Epoch 8/80
# 67/67 [==============================] - 26s 390ms/step - loss: 0.2511 - accuracy: 0.0148 - val_loss: 0.2963 - val_accuracy: 0.0100 - lr: 0.0010
# Epoch 9/80
# 67/67 [==============================] - 26s 393ms/step - loss: 0.2492 - accuracy: 0.0153 - val_loss: 0.3023 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 10/80
# 67/67 [==============================] - 27s 401ms/step - loss: 0.2433 - accuracy: 0.0156 - val_loss: 0.3015 - val_accuracy: 0.0128 - lr: 1.0000e-04
# Epoch 11/80
# 67/67 [==============================] - 27s 399ms/step - loss: 0.2437 - accuracy: 0.0161 - val_loss: 0.2998 - val_accuracy: 0.0128 - lr: 1.0000e-04
# Epoch 12/80
# 67/67 [==============================] - 27s 397ms/step - loss: 0.2437 - accuracy: 0.0153 - val_loss: 0.2976 - val_accuracy: 0.0128 - lr: 1.0000e-04
# Epoch 13/80
# 67/67 [==============================] - 26s 390ms/step - loss: 0.2419 - accuracy: 0.0166 - val_loss: 0.2978 - val_accuracy: 0.0114 - lr: 1.0000e-04
# Epoch 14/80
# 67/67 [==============================] - 26s 396ms/step - loss: 0.2425 - accuracy: 0.0164 - val_loss: 0.2982 - val_accuracy: 0.0128 - lr: 1.0000e-04
#
#  pred
#  0.0    1469
# -1.0      84
#  1.0      44
# dtype: int64 --------------------------------
# 2015-10-26, BUY CREATE, 32900.00
# 2015-10-27, BUY EXECUTED, Price: 32100.00, Cost: 9726300.00, Comm 0.00
# 2016-11-03, SELL CREATE, 41150.00
# 2016-11-04, SELL EXECUTED, Price: 41150.00, Cost: 32100.00, Comm 0.00
# 2016-11-04, SELL CREATE, 41200.00
# 2016-11-07, SELL EXECUTED, Price: 41800.00, Cost: 32100.00, Comm 0.00
# 2016-11-07, SELL CREATE, 41500.00
# 2016-11-08, SELL EXECUTED, Price: 42100.00, Cost: 32100.00, Comm 0.00
# 2016-11-08, SELL CREATE, 41500.00
# 2016-11-09, SELL EXECUTED, Price: 41650.00, Cost: 32100.00, Comm 0.00
# 2016-11-09, SELL CREATE, 39650.00
# 2016-11-10, SELL EXECUTED, Price: 41000.00, Cost: 32100.00, Comm 0.00
# 2016-11-10, SELL CREATE, 41000.00
# 2016-11-11, SELL EXECUTED, Price: 40000.00, Cost: 32100.00, Comm 0.00
# 2016-11-11, SELL CREATE, 39850.00
# 2019-11-15, SELL EXECUTED, Price: 84200.00, Cost: 32100.00, Comm 0.00
# 2019-11-15, SELL CREATE, 85200.00
# 2019-11-18, SELL EXECUTED, Price: 86000.00, Cost: 32100.00, Comm 0.00
# 2019-11-18, SELL CREATE, 85500.00
# 2019-11-19, SELL EXECUTED, Price: 85400.00, Cost: 32100.00, Comm 0.00
# 2019-11-19, SELL CREATE, 85300.00
# 2019-11-20, SELL EXECUTED, Price: 84400.00, Cost: 32100.00, Comm 0.00
# 2020-03-11, SELL CREATE, 85500.00
# 2020-03-12, SELL EXECUTED, Price: 83800.00, Cost: 32100.00, Comm 0.00
# 2020-03-12, SELL CREATE, 82800.00
# 2020-03-13, SELL EXECUTED, Price: 76900.00, Cost: 32100.00, Comm 0.00
# 2020-03-13, SELL CREATE, 82500.00
# 2020-03-16, SELL EXECUTED, Price: 83700.00, Cost: 32100.00, Comm 0.00
# 2021-01-08, SELL CREATE, 138000.00
# 2021-01-11, SELL EXECUTED, Price: 138000.00, Cost: 32100.00, Comm 0.00
# 2021-01-11, SELL CREATE, 133000.00
# 2021-01-12, SELL EXECUTED, Price: 132000.00, Cost: 32100.00, Comm 0.00
# 2021-01-12, SELL CREATE, 129000.00
# 2021-01-13, SELL EXECUTED, Price: 129000.00, Cost: 32100.00, Comm 0.00
# mdd : 36.92, cagr: 23.40
# 최종금액 :  37683050.0 원
# 수익률 :  276.8305 %
#
#
# ['KR7000660001', 4677.0, 1537.0, 36.92435798630489, 23.39958894964489, 276.8305]
# WARNING:tensorflow:Layer gru_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_37 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_38 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 51/51 [==============================] - 26s 410ms/step - loss: 0.3215 - accuracy: 0.0103 - val_loss: 0.3224 - val_accuracy: 0.0019 - lr: 0.0010
# Epoch 2/80
# 51/51 [==============================] - 20s 395ms/step - loss: 0.3006 - accuracy: 0.0117 - val_loss: 0.2821 - val_accuracy: 0.0075 - lr: 0.0010
# Epoch 3/80
# 51/51 [==============================] - 20s 397ms/step - loss: 0.2840 - accuracy: 0.0137 - val_loss: 0.2788 - val_accuracy: 0.0019 - lr: 0.0010
# Epoch 4/80
# 51/51 [==============================] - 20s 392ms/step - loss: 0.2796 - accuracy: 0.0127 - val_loss: 0.2737 - val_accuracy: 0.0038 - lr: 0.0010
# Epoch 5/80
# 51/51 [==============================] - 20s 391ms/step - loss: 0.2753 - accuracy: 0.0133 - val_loss: 0.2736 - val_accuracy: 0.0038 - lr: 0.0010
# Epoch 6/80
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2691 - accuracy: 0.0133 - val_loss: 0.2748 - val_accuracy: 0.0056 - lr: 0.0010
# Epoch 7/80
# 51/51 [==============================] - 20s 388ms/step - loss: 0.2662 - accuracy: 0.0140 - val_loss: 0.2856 - val_accuracy: 0.0038 - lr: 0.0010
# Epoch 8/80
# 51/51 [==============================] - 20s 390ms/step - loss: 0.2640 - accuracy: 0.0137 - val_loss: 0.2688 - val_accuracy: 0.0075 - lr: 0.0010
# Epoch 9/80
# 51/51 [==============================] - 20s 387ms/step - loss: 0.2617 - accuracy: 0.0127 - val_loss: 0.2753 - val_accuracy: 0.0056 - lr: 0.0010
# Epoch 10/80
# 51/51 [==============================] - 20s 398ms/step - loss: 0.2589 - accuracy: 0.0143 - val_loss: 0.2708 - val_accuracy: 0.0019 - lr: 0.0010
# Epoch 11/80
# 51/51 [==============================] - 20s 392ms/step - loss: 0.2552 - accuracy: 0.0153 - val_loss: 0.2730 - val_accuracy: 0.0038 - lr: 0.0010
# Epoch 12/80
# 51/51 [==============================] - 20s 395ms/step - loss: 0.2505 - accuracy: 0.0143 - val_loss: 0.2748 - val_accuracy: 0.0075 - lr: 0.0010
# Epoch 13/80
# 51/51 [==============================] - 20s 396ms/step - loss: 0.2436 - accuracy: 0.0153 - val_loss: 0.2717 - val_accuracy: 0.0094 - lr: 0.0010
# Epoch 14/80
# 51/51 [==============================] - 20s 392ms/step - loss: 0.2392 - accuracy: 0.0157 - val_loss: 0.2662 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 15/80
# 51/51 [==============================] - 20s 391ms/step - loss: 0.2359 - accuracy: 0.0150 - val_loss: 0.2705 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 16/80
# 51/51 [==============================] - 20s 391ms/step - loss: 0.2313 - accuracy: 0.0170 - val_loss: 0.2749 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 17/80
# 51/51 [==============================] - 20s 395ms/step - loss: 0.2272 - accuracy: 0.0183 - val_loss: 0.2759 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 18/80
# 51/51 [==============================] - 20s 397ms/step - loss: 0.2306 - accuracy: 0.0170 - val_loss: 0.2686 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 19/80
# 51/51 [==============================] - 20s 397ms/step - loss: 0.2292 - accuracy: 0.0183 - val_loss: 0.2707 - val_accuracy: 0.0075 - lr: 1.0000e-04
# Epoch 20/80
# 51/51 [==============================] - 20s 399ms/step - loss: 0.2289 - accuracy: 0.0186 - val_loss: 0.2708 - val_accuracy: 0.0075 - lr: 1.0000e-05
# Epoch 21/80
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2244 - accuracy: 0.0183 - val_loss: 0.2714 - val_accuracy: 0.0075 - lr: 1.0000e-05
# Epoch 22/80
# 51/51 [==============================] - 20s 394ms/step - loss: 0.2248 - accuracy: 0.0180 - val_loss: 0.2708 - val_accuracy: 0.0075 - lr: 1.0000e-05
# Epoch 23/80
# 51/51 [==============================] - 20s 395ms/step - loss: 0.2259 - accuracy: 0.0183 - val_loss: 0.2726 - val_accuracy: 0.0075 - lr: 1.0000e-05
# Epoch 24/80
# 51/51 [==============================] - 20s 400ms/step - loss: 0.2259 - accuracy: 0.0170 - val_loss: 0.2727 - val_accuracy: 0.0075 - lr: 1.0000e-05
#
#  pred
#  0.0    1013
#  1.0     147
# -1.0      57
# dtype: int64 --------------------------------
# 2017-06-16, BUY CREATE, 892000.00
# 2017-06-19, BUY EXECUTED, Price: 887000.00, Cost: 9757000.00, Comm 0.00
# 2017-07-26, SELL CREATE, 825000.00
# 2017-07-27, SELL EXECUTED, Price: 820000.00, Cost: 887000.00, Comm 0.00
# 2017-07-27, SELL CREATE, 825000.00
# 2017-07-28, SELL EXECUTED, Price: 821000.00, Cost: 887000.00, Comm 0.00
# 2017-07-28, SELL CREATE, 799000.00
# 2017-07-31, SELL EXECUTED, Price: 799000.00, Cost: 887000.00, Comm 0.00
# 2017-07-31, SELL CREATE, 803000.00
# 2017-08-01, SELL EXECUTED, Price: 794000.00, Cost: 887000.00, Comm 0.00
# 2017-08-01, SELL CREATE, 796000.00
# 2017-08-02, SELL EXECUTED, Price: 792000.00, Cost: 887000.00, Comm 0.00
# 2017-08-03, SELL CREATE, 778000.00
# 2017-08-04, SELL EXECUTED, Price: 779000.00, Cost: 887000.00, Comm 0.00
# 2017-08-07, SELL CREATE, 796000.00
# 2017-08-08, SELL EXECUTED, Price: 801000.00, Cost: 887000.00, Comm 0.00
# 2017-10-10, SELL CREATE, 756000.00
# 2017-10-11, SELL EXECUTED, Price: 751000.00, Cost: 887000.00, Comm 0.00
# 2017-10-11, SELL CREATE, 751000.00
# 2017-10-12, SELL EXECUTED, Price: 751000.00, Cost: 887000.00, Comm 0.00
# 2017-10-12, SELL CREATE, 768000.00
# 2017-10-13, SELL EXECUTED, Price: 768000.00, Cost: 887000.00, Comm 0.00
# 2017-10-13, SELL CREATE, 762000.00
# 2017-10-16, SELL EXECUTED, Price: 764000.00, Cost: 887000.00, Comm 0.00
# 2017-10-16, OPERATION PROFIT, GROSS -1117000.00, NET -1117000.00
# 2018-03-02, BUY CREATE, 786000.00
# 2018-03-05, BUY EXECUTED, Price: 786000.00, Cost: 8646000.00, Comm 0.00
# 2018-04-06, SELL CREATE, 770000.00
# 2018-04-09, SELL EXECUTED, Price: 769000.00, Cost: 786000.00, Comm 0.00
# 2018-04-09, SELL CREATE, 774000.00
# 2018-04-10, SELL EXECUTED, Price: 771000.00, Cost: 786000.00, Comm 0.00
# 2018-04-10, SELL CREATE, 775000.00
# 2018-04-11, SELL EXECUTED, Price: 772000.00, Cost: 786000.00, Comm 0.00
# 2018-04-12, SELL CREATE, 757000.00
# 2018-04-13, SELL EXECUTED, Price: 758000.00, Cost: 786000.00, Comm 0.00
# 2018-04-13, SELL CREATE, 764000.00
# 2018-04-16, SELL EXECUTED, Price: 765000.00, Cost: 786000.00, Comm 0.00
# 2018-04-16, SELL CREATE, 751000.00
# 2018-04-17, SELL EXECUTED, Price: 754000.00, Cost: 786000.00, Comm 0.00
# 2018-05-15, SELL CREATE, 711000.00
# 2018-05-16, SELL EXECUTED, Price: 712000.00, Cost: 786000.00, Comm 0.00
# 2018-05-16, SELL CREATE, 700000.00
# 2018-05-17, SELL EXECUTED, Price: 700000.00, Cost: 786000.00, Comm 0.00
# 2018-05-17, SELL CREATE, 697000.00
# 2018-05-18, SELL EXECUTED, Price: 697000.00, Cost: 786000.00, Comm 0.00
# 2018-05-18, SELL CREATE, 688000.00
# 2018-05-21, SELL EXECUTED, Price: 686000.00, Cost: 786000.00, Comm 0.00
# 2018-05-21, SELL CREATE, 682000.00
# 2018-05-23, SELL EXECUTED, Price: 680000.00, Cost: 786000.00, Comm 0.00
# 2018-05-23, OPERATION PROFIT, GROSS -582000.00, NET -582000.00
# 2018-07-11, BUY CREATE, 769000.00
# 2018-07-12, BUY EXECUTED, Price: 775000.00, Cost: 7750000.00, Comm 0.00
# 2018-08-02, SELL CREATE, 728000.00
# 2018-08-03, SELL EXECUTED, Price: 723000.00, Cost: 775000.00, Comm 0.00
# 2018-08-03, SELL CREATE, 731000.00
# 2018-08-06, SELL EXECUTED, Price: 733000.00, Cost: 775000.00, Comm 0.00
# 2018-12-04, SELL CREATE, 123500.00
# 2018-12-05, SELL EXECUTED, Price: 124500.00, Cost: 775000.00, Comm 0.00
# 2018-12-05, SELL CREATE, 125000.00
# 2018-12-06, SELL EXECUTED, Price: 123000.00, Cost: 775000.00, Comm 0.00
# 2018-12-06, SELL CREATE, 120000.00
# 2018-12-07, SELL EXECUTED, Price: 121500.00, Cost: 775000.00, Comm 0.00
# 2018-12-07, SELL CREATE, 121000.00
# 2018-12-10, SELL EXECUTED, Price: 119000.00, Cost: 775000.00, Comm 0.00
# 2018-12-28, SELL CREATE, 122000.00
# 2019-01-02, SELL EXECUTED, Price: 121000.00, Cost: 775000.00, Comm 0.00
# 2019-01-04, SELL CREATE, 125500.00
# 2019-01-07, SELL EXECUTED, Price: 128000.00, Cost: 775000.00, Comm 0.00
# 2019-01-07, SELL CREATE, 131500.00
# 2019-01-08, SELL EXECUTED, Price: 132000.00, Cost: 775000.00, Comm 0.00
# 2019-02-07, SELL CREATE, 129000.00
# 2019-02-08, SELL EXECUTED, Price: 126500.00, Cost: 775000.00, Comm 0.00
# 2019-02-08, OPERATION PROFIT, GROSS -5298500.00, NET -5298500.00
# 2019-03-22, BUY CREATE, 127000.00
# 2019-03-25, BUY EXECUTED, Price: 126000.00, Cost: 2898000.00, Comm 0.00
# 2019-11-22, SELL CREATE, 167500.00
# 2019-11-25, SELL EXECUTED, Price: 168000.00, Cost: 126000.00, Comm 0.00
# 2019-11-25, SELL CREATE, 174000.00
# 2019-11-26, SELL EXECUTED, Price: 173500.00, Cost: 126000.00, Comm 0.00
# 2019-11-27, SELL CREATE, 172500.00
# 2019-11-28, SELL EXECUTED, Price: 172500.00, Cost: 126000.00, Comm 0.00
# 2019-11-28, SELL CREATE, 173000.00
# 2019-11-29, SELL EXECUTED, Price: 173000.00, Cost: 126000.00, Comm 0.00
# 2020-05-15, SELL CREATE, 213000.00
# 2020-05-18, SELL EXECUTED, Price: 215000.00, Cost: 126000.00, Comm 0.00
# 2020-05-18, SELL CREATE, 215000.00
# 2020-05-19, SELL EXECUTED, Price: 215000.00, Cost: 126000.00, Comm 0.00
# 2020-05-19, SELL CREATE, 213500.00
# 2020-05-20, SELL EXECUTED, Price: 215500.00, Cost: 126000.00, Comm 0.00
# 2020-05-20, SELL CREATE, 222000.00
# 2020-05-21, SELL EXECUTED, Price: 227500.00, Cost: 126000.00, Comm 0.00
# Epoch 38/80
# 14/14 [==============================] - 5s 390ms/step - loss: 0.1931 - accuracy: 0.0127 - val_loss: 0.2297 - val_accuracy: 0.0072 - lr: 1.0000e-05
#
#  pred
#  0.0    304
#  1.0     30
# -1.0     13
# dtype: int64 --------------------------------
# 2020-11-26, BUY CREATE, 799000.00
# 2020-11-27, BUY EXECUTED, Price: 799000.00, Cost: 9588000.00, Comm 0.00
# 2021-05-20, SELL CREATE, 891000.00
# 2021-05-21, SELL EXECUTED, Price: 887000.00, Cost: 799000.00, Comm 0.00
# 2021-05-21, SELL CREATE, 861000.00
# 2021-05-24, SELL EXECUTED, Price: 880000.00, Cost: 799000.00, Comm 0.00
# 2021-05-24, SELL CREATE, 858000.00
# 2021-05-25, SELL EXECUTED, Price: 858000.00, Cost: 799000.00, Comm 0.00
# 2021-05-25, SELL CREATE, 850000.00
# 2021-05-26, SELL EXECUTED, Price: 850000.00, Cost: 799000.00, Comm 0.00
# 2021-05-26, SELL CREATE, 835000.00
# 2021-05-27, SELL EXECUTED, Price: 824000.00, Cost: 799000.00, Comm 0.00
# 2021-05-27, SELL CREATE, 817000.00
# 2021-05-28, SELL EXECUTED, Price: 817000.00, Cost: 799000.00, Comm 0.00
# 2021-05-28, SELL CREATE, 827000.00
# 2021-05-31, SELL EXECUTED, Price: 828000.00, Cost: 799000.00, Comm 0.00
# 2021-05-31, SELL CREATE, 845000.00
# 2021-06-01, SELL EXECUTED, Price: 865000.00, Cost: 799000.00, Comm 0.00
# 2021-06-01, SELL CREATE, 832000.00
# 2021-06-02, SELL EXECUTED, Price: 833000.00, Cost: 799000.00, Comm 0.00
# 2021-06-02, SELL CREATE, 818000.00
# 2021-06-03, SELL EXECUTED, Price: 822000.00, Cost: 799000.00, Comm 0.00
# 2021-06-03, SELL CREATE, 824000.00
# 2021-06-04, SELL EXECUTED, Price: 819000.00, Cost: 799000.00, Comm 0.00
# 2021-06-04, SELL CREATE, 840000.00
# 2021-06-07, SELL EXECUTED, Price: 852000.00, Cost: 799000.00, Comm 0.00
# 2021-06-07, OPERATION PROFIT, GROSS 547000.00, NET 547000.00
# 2021-07-08, BUY CREATE, 863000.00
# 2021-07-09, BUY EXECUTED, Price: 863000.00, Cost: 10356000.00, Comm 0.00
# 2021-09-27, SELL CREATE, 920000.00
# 2021-09-28, SELL EXECUTED, Price: 913000.00, Cost: 863000.00, Comm 0.00
# 2021-09-28, SELL CREATE, 871000.00
# 2021-09-29, SELL EXECUTED, Price: 854000.00, Cost: 863000.00, Comm 0.00
# mdd : 21.33, cagr: 7.23
# 최종금액 :  10988000.0 원
# 수익률 :  9.879999999999999 %
#
#
# ['KR7207940008', 925.0, 287.0, 21.327014218009477, 7.232872830245983, 9.879999999999999]
# WARNING:tensorflow:Layer gru_42 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_43 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_44 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 72/72 [==============================] - 33s 394ms/step - loss: 0.2925 - accuracy: 0.0110 - val_loss: 0.3022 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 2/80
# 72/72 [==============================] - 27s 382ms/step - loss: 0.2624 - accuracy: 0.0126 - val_loss: 0.2830 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 3/80
# 72/72 [==============================] - 27s 381ms/step - loss: 0.2530 - accuracy: 0.0133 - val_loss: 0.3074 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 4/80
# 72/72 [==============================] - 28s 387ms/step - loss: 0.2506 - accuracy: 0.0135 - val_loss: 0.2999 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 5/80
# 72/72 [==============================] - 28s 391ms/step - loss: 0.2447 - accuracy: 0.0133 - val_loss: 0.3101 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 6/80
# 72/72 [==============================] - 28s 394ms/step - loss: 0.2441 - accuracy: 0.0128 - val_loss: 0.2922 - val_accuracy: 0.0079 - lr: 0.0010
# Epoch 7/80
# 72/72 [==============================] - 28s 384ms/step - loss: 0.2363 - accuracy: 0.0126 - val_loss: 0.3420 - val_accuracy: 0.0092 - lr: 0.0010
# Epoch 8/80
# 72/72 [==============================] - 28s 386ms/step - loss: 0.2291 - accuracy: 0.0128 - val_loss: 0.2852 - val_accuracy: 0.0092 - lr: 1.0000e-04
# Epoch 9/80
# 72/72 [==============================] - 28s 387ms/step - loss: 0.2242 - accuracy: 0.0133 - val_loss: 0.2853 - val_accuracy: 0.0092 - lr: 1.0000e-04
# Epoch 10/80
# 72/72 [==============================] - 28s 385ms/step - loss: 0.2194 - accuracy: 0.0147 - val_loss: 0.2847 - val_accuracy: 0.0092 - lr: 1.0000e-04
# Epoch 11/80
# 72/72 [==============================] - 28s 385ms/step - loss: 0.2209 - accuracy: 0.0138 - val_loss: 0.2878 - val_accuracy: 0.0079 - lr: 1.0000e-04
# Epoch 12/80
# 72/72 [==============================] - 27s 380ms/step - loss: 0.2189 - accuracy: 0.0135 - val_loss: 0.2882 - val_accuracy: 0.0092 - lr: 1.0000e-04
#
#  pred
#  0.0    1517
# -1.0     112
#  1.0      90
# dtype: int64 --------------------------------
# 2015-02-10, BUY CREATE, 1071000.00
# 2015-02-11, BUY EXECUTED, Price: 1059000.00, Cost: 9531000.00, Comm 0.00
# 2015-07-27, SELL CREATE, 955000.00
# 2015-07-28, SELL EXECUTED, Price: 950000.00, Cost: 1059000.00, Comm 0.00
# 2015-07-28, SELL CREATE, 940000.00
# 2015-07-29, SELL EXECUTED, Price: 951000.00, Cost: 1059000.00, Comm 0.00
# 2015-07-29, SELL CREATE, 965000.00
# 2015-07-30, SELL EXECUTED, Price: 965000.00, Cost: 1059000.00, Comm 0.00
# 2015-07-30, SELL CREATE, 926000.00
# 2015-07-31, SELL EXECUTED, Price: 929000.00, Cost: 1059000.00, Comm 0.00
# 2015-07-31, SELL CREATE, 920000.00
# 2015-08-03, SELL EXECUTED, Price: 915000.00, Cost: 1059000.00, Comm 0.00
# 2015-08-03, SELL CREATE, 908000.00
# 2015-08-04, SELL EXECUTED, Price: 913000.00, Cost: 1059000.00, Comm 0.00
# 2015-08-04, SELL CREATE, 920000.00
# 2015-08-05, SELL EXECUTED, Price: 920000.00, Cost: 1059000.00, Comm 0.00
# 2015-08-05, SELL CREATE, 896000.00
# 2015-08-06, SELL EXECUTED, Price: 901000.00, Cost: 1059000.00, Comm 0.00
# 2015-08-06, SELL CREATE, 877000.00
# 2015-08-07, SELL EXECUTED, Price: 866000.00, Cost: 1059000.00, Comm 0.00
# 2015-08-07, OPERATION PROFIT, GROSS -1221000.00, NET -1221000.00
# 2015-10-21, BUY CREATE, 998000.00
# 2015-10-22, BUY EXECUTED, Price: 1012000.00, Cost: 8096000.00, Comm 0.00
# 2016-05-13, SELL CREATE, 1033000.00
# 2016-05-16, SELL EXECUTED, Price: 1033000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-16, SELL CREATE, 1026000.00
# 2016-05-17, SELL EXECUTED, Price: 1028000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-17, SELL CREATE, 1032000.00
# 2016-05-18, SELL EXECUTED, Price: 1032000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-18, SELL CREATE, 1022000.00
# 2016-05-19, SELL EXECUTED, Price: 1032000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-19, SELL CREATE, 1032000.00
# 2016-05-20, SELL EXECUTED, Price: 1035000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-20, SELL CREATE, 1032000.00
# 2016-05-23, SELL EXECUTED, Price: 1042000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-23, SELL CREATE, 1037000.00
# 2016-05-24, SELL EXECUTED, Price: 1040000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-24, SELL CREATE, 1041000.00
# 2016-05-25, SELL EXECUTED, Price: 1052000.00, Cost: 1012000.00, Comm 0.00
# 2016-05-25, OPERATION PROFIT, GROSS 198000.00, NET 198000.00
# 2016-07-13, BUY CREATE, 1196000.00
# 2016-07-14, BUY EXECUTED, Price: 1198000.00, Cost: 8386000.00, Comm 0.00
# 2017-04-24, SELL CREATE, 1586000.00
# 2017-04-25, SELL EXECUTED, Price: 1587000.00, Cost: 1198000.00, Comm 0.00
# 2017-04-25, SELL CREATE, 1634000.00
# 2017-04-26, SELL EXECUTED, Price: 1634000.00, Cost: 1198000.00, Comm 0.00
# 2017-04-26, SELL CREATE, 1641000.00
# 2017-04-27, SELL EXECUTED, Price: 1647000.00, Cost: 1198000.00, Comm 0.00
# 2017-06-27, SELL CREATE, 1921000.00
# 2017-06-28, SELL EXECUTED, Price: 1901000.00, Cost: 1198000.00, Comm 0.00
# 2017-06-28, SELL CREATE, 1881000.00
# 2017-06-29, SELL EXECUTED, Price: 1897000.00, Cost: 1198000.00, Comm 0.00
# 2017-06-29, SELL CREATE, 1900000.00
# 2017-06-30, SELL EXECUTED, Price: 1883000.00, Cost: 1198000.00, Comm 0.00
# 2017-06-30, SELL CREATE, 1862000.00
# 2017-07-03, SELL EXECUTED, Price: 1867000.00, Cost: 1198000.00, Comm 0.00
# 2017-07-03, OPERATION PROFIT, GROSS 4030000.00, NET 4030000.00
# 2017-08-31, BUY CREATE, 1885000.00
# 2017-09-01, BUY EXECUTED, Price: 1907000.00, Cost: 11442000.00, Comm 0.00
# 2017-10-27, SELL CREATE, 2116000.00
# 2017-10-30, SELL EXECUTED, Price: 2138000.00, Cost: 1907000.00, Comm 0.00
# 2017-10-30, SELL CREATE, 2135000.00
# 2017-10-31, SELL EXECUTED, Price: 2135000.00, Cost: 1907000.00, Comm 0.00
# 2017-10-31, SELL CREATE, 2240000.00
# 2017-11-01, SELL EXECUTED, Price: 2336000.00, Cost: 1907000.00, Comm 0.00
# 2017-11-01, SELL CREATE, 2335000.00
# 2017-11-02, SELL EXECUTED, Price: 2348000.00, Cost: 1907000.00, Comm 0.00
# 2017-11-02, SELL CREATE, 2329000.00
# 2017-11-03, SELL EXECUTED, Price: 2329000.00, Cost: 1907000.00, Comm 0.00
# 2017-11-03, SELL CREATE, 2300000.00
# 2017-11-06, SELL EXECUTED, Price: 2324000.00, Cost: 1907000.00, Comm 0.00
# 2017-11-06, OPERATION PROFIT, GROSS 2168000.00, NET 2168000.00
# 2018-02-14, BUY CREATE, 2037000.00
# 2018-02-19, BUY EXECUTED, Price: 2088000.00, Cost: 14616000.00, Comm 0.00
# 2018-08-13, SELL CREATE, 36700.00
# 2018-08-14, SELL EXECUTED, Price: 36500.00, Cost: 2088000.00, Comm 0.00
# 2018-08-14, SELL CREATE, 36850.00
# 2018-08-16, SELL EXECUTED, Price: 36000.00, Cost: 2088000.00, Comm 0.00
# 2018-08-16, SELL CREATE, 35600.00
# 2018-08-17, SELL EXECUTED, Price: 35950.00, Cost: 2088000.00, Comm 0.00
# 2018-11-13, SELL CREATE, 37350.00
# 2018-11-14, SELL EXECUTED, Price: 37500.00, Cost: 2088000.00, Comm 0.00
# 2018-11-14, SELL CREATE, 37050.00
# 2018-11-15, SELL EXECUTED, Price: 37000.00, Cost: 2088000.00, Comm 0.00
# 2018-11-15, SELL CREATE, 36750.00
# 2018-11-16, SELL EXECUTED, Price: 37100.00, Cost: 2088000.00, Comm 0.00
# 2019-01-09, SELL CREATE, 32500.00
# 2019-01-10, SELL EXECUTED, Price: 32350.00, Cost: 2088000.00, Comm 0.00
# 2019-01-10, OPERATION PROFIT, GROSS -14363600.00, NET -14363600.00
# 2019-02-18, BUY CREATE, 36900.00
# 2019-02-19, BUY EXECUTED, Price: 37200.00, Cost: 781200.00, Comm 0.00
# 2019-06-26, SELL CREATE, 37900.00
# 2019-06-27, SELL EXECUTED, Price: 37600.00, Cost: 37200.00, Comm 0.00
# 2019-10-11, SELL CREATE, 40000.00
# 2019-10-14, SELL EXECUTED, Price: 40700.00, Cost: 37200.00, Comm 0.00
# 2019-10-14, SELL CREATE, 40600.00
# 2019-10-15, SELL EXECUTED, Price: 40600.00, Cost: 37200.00, Comm 0.00
# 2019-10-15, SELL CREATE, 40600.00
# 2019-10-16, SELL EXECUTED, Price: 40700.00, Cost: 37200.00, Comm 0.00
# 2019-10-16, SELL CREATE, 41100.00
# 2019-10-17, SELL EXECUTED, Price: 40650.00, Cost: 37200.00, Comm 0.00
# 2019-10-17, SELL CREATE, 40900.00
# 2019-10-18, SELL EXECUTED, Price: 40700.00, Cost: 37200.00, Comm 0.00
# 2019-10-18, SELL CREATE, 40300.00
# 2019-10-21, SELL EXECUTED, Price: 40300.00, Cost: 37200.00, Comm 0.00
# 2019-10-21, SELL CREATE, 40600.00
# 2019-10-22, SELL EXECUTED, Price: 40800.00, Cost: 37200.00, Comm 0.00
# 2019-10-22, SELL CREATE, 41500.00
# 2019-10-23, SELL EXECUTED, Price: 41250.00, Cost: 37200.00, Comm 0.00
# 2019-10-23, SELL CREATE, 41400.00
# 2019-10-24, SELL EXECUTED, Price: 41800.00, Cost: 37200.00, Comm 0.00
# 2019-10-24, SELL CREATE, 41650.00
# 2019-10-25, SELL EXECUTED, Price: 41300.00, Cost: 37200.00, Comm 0.00
# 2019-11-18, SELL CREATE, 42950.00
# 2019-11-19, SELL EXECUTED, Price: 42850.00, Cost: 37200.00, Comm 0.00
# 2019-11-19, SELL CREATE, 43050.00
# 2019-11-20, SELL EXECUTED, Price: 42750.00, Cost: 37200.00, Comm 0.00
# 2020-10-14, SELL CREATE, 53600.00
# 2020-10-15, SELL EXECUTED, Price: 53100.00, Cost: 37200.00, Comm 0.00
# 2020-10-15, SELL CREATE, 53200.00
# 2020-10-16, SELL EXECUTED, Price: 53400.00, Cost: 37200.00, Comm 0.00
# 2020-10-16, SELL CREATE, 53000.00
# 2020-10-19, SELL EXECUTED, Price: 52800.00, Cost: 37200.00, Comm 0.00
# 2020-10-19, SELL CREATE, 53000.00
# 2020-10-20, SELL EXECUTED, Price: 52900.00, Cost: 37200.00, Comm 0.00
# ...
# 2020-05-20, SELL CREATE, 97300.00
# 2020-05-21, SELL EXECUTED, Price: 98600.00, Cost: 126000.00, Comm 0.00
# 2020-05-21, SELL CREATE, 97200.00
# 2020-05-22, SELL EXECUTED, Price: 97100.00, Cost: 126000.00, Comm 0.00
# 2020-05-22, SELL CREATE, 94500.00
# 2020-05-25, SELL EXECUTED, Price: 94900.00, Cost: 126000.00, Comm 0.00
# 2020-05-25, SELL CREATE, 96000.00
# 2020-05-26, SELL EXECUTED, Price: 96000.00, Cost: 126000.00, Comm 0.00
# 2020-05-26, OPERATION PROFIT, GROSS -276700.00, NET -276700.00
# 2020-07-28, BUY CREATE, 123000.00
# 2020-07-29, BUY EXECUTED, Price: 122500.00, Cost: 6615000.00, Comm 0.00
# 2020-08-19, SELL CREATE, 164500.00
# 2020-08-20, SELL EXECUTED, Price: 163000.00, Cost: 122500.00, Comm 0.00
# 2020-08-20, SELL CREATE, 155000.00
# 2020-08-21, SELL EXECUTED, Price: 158000.00, Cost: 122500.00, Comm 0.00
# 2020-08-21, SELL CREATE, 156000.00
# 2020-08-24, SELL EXECUTED, Price: 157500.00, Cost: 122500.00, Comm 0.00
# 2020-08-24, SELL CREATE, 161500.00
# 2020-08-25, SELL EXECUTED, Price: 167500.00, Cost: 122500.00, Comm 0.00
# 2020-08-25, SELL CREATE, 166000.00
# 2020-08-26, SELL EXECUTED, Price: 166500.00, Cost: 122500.00, Comm 0.00
# 2020-08-26, SELL CREATE, 167500.00
# 2020-08-27, SELL EXECUTED, Price: 169000.00, Cost: 122500.00, Comm 0.00
# 2020-09-07, SELL CREATE, 170000.00
# 2020-09-08, SELL EXECUTED, Price: 171000.00, Cost: 122500.00, Comm 0.00
# 2020-09-08, SELL CREATE, 168000.00
# 2020-09-09, SELL EXECUTED, Price: 166500.00, Cost: 122500.00, Comm 0.00
# 2020-10-27, SELL CREATE, 172500.00
# 2020-10-28, SELL EXECUTED, Price: 172000.00, Cost: 122500.00, Comm 0.00
# 2021-01-13, SELL CREATE, 259000.00
# 2021-01-14, SELL EXECUTED, Price: 251000.00, Cost: 122500.00, Comm 0.00
# mdd : 36.23, cagr: 1.40
# 최종금액 :  10988300.0 원
# 수익률 :  9.883000000000001 %
#
#
# ['KR7005380001', 5043.0, 1659.0, 36.225, 1.3969327348890561, 9.883000000000001]
# WARNING:tensorflow:Layer gru_54 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_55 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_56 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 55/55 [==============================] - 26s 396ms/step - loss: 0.3300 - accuracy: 0.0111 - val_loss: 0.2922 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 2/80
# 55/55 [==============================] - 21s 388ms/step - loss: 0.3031 - accuracy: 0.0120 - val_loss: 0.2757 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 3/80
# 55/55 [==============================] - 21s 381ms/step - loss: 0.2912 - accuracy: 0.0117 - val_loss: 0.2778 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 4/80
# 55/55 [==============================] - 21s 382ms/step - loss: 0.2855 - accuracy: 0.0130 - val_loss: 0.2849 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 5/80
# 55/55 [==============================] - 21s 387ms/step - loss: 0.2844 - accuracy: 0.0120 - val_loss: 0.2857 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 6/80
# 55/55 [==============================] - 21s 386ms/step - loss: 0.2791 - accuracy: 0.0127 - val_loss: 0.2870 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 7/80
# 55/55 [==============================] - 21s 388ms/step - loss: 0.2802 - accuracy: 0.0123 - val_loss: 0.3104 - val_accuracy: 0.0070 - lr: 0.0010
# Epoch 8/80
# 55/55 [==============================] - 21s 377ms/step - loss: 0.2739 - accuracy: 0.0120 - val_loss: 0.2834 - val_accuracy: 0.0070 - lr: 1.0000e-04
# Epoch 9/80
# 55/55 [==============================] - 21s 377ms/step - loss: 0.2684 - accuracy: 0.0130 - val_loss: 0.2852 - val_accuracy: 0.0070 - lr: 1.0000e-04
# Epoch 10/80
# 55/55 [==============================] - 21s 375ms/step - loss: 0.2697 - accuracy: 0.0127 - val_loss: 0.2855 - val_accuracy: 0.0070 - lr: 1.0000e-04
# Epoch 11/80
# 55/55 [==============================] - 20s 372ms/step - loss: 0.2660 - accuracy: 0.0133 - val_loss: 0.2867 - val_accuracy: 0.0070 - lr: 1.0000e-04
# Epoch 12/80
# 55/55 [==============================] - 21s 383ms/step - loss: 0.2673 - accuracy: 0.0130 - val_loss: 0.2856 - val_accuracy: 0.0070 - lr: 1.0000e-04
#
#  pred
#  0.0    1261
# -1.0      29
#  1.0      19
# dtype: int64 --------------------------------
# 2016-10-31, BUY CREATE, 246500.00
# 2016-11-01, BUY EXECUTED, Price: 245500.00, Cost: 9820000.00, Comm 0.00
# 2017-02-28, SELL CREATE, 283000.00
# 2017-03-02, SELL EXECUTED, Price: 286000.00, Cost: 245500.00, Comm 0.00
# 2017-03-02, SELL CREATE, 287500.00
# 2017-03-03, SELL EXECUTED, Price: 287500.00, Cost: 245500.00, Comm 0.00
# 2017-06-22, SELL CREATE, 287000.00
# 2017-06-23, SELL EXECUTED, Price: 287500.00, Cost: 245500.00, Comm 0.00
# 2018-05-09, SELL CREATE, 339500.00
# 2018-05-10, SELL EXECUTED, Price: 339500.00, Cost: 245500.00, Comm 0.00
# 2018-05-10, SELL CREATE, 340000.00
# 2018-05-11, SELL EXECUTED, Price: 343500.00, Cost: 245500.00, Comm 0.00
# 2019-01-11, SELL CREATE, 349000.00
# 2019-01-14, SELL EXECUTED, Price: 349000.00, Cost: 245500.00, Comm 0.00
# 2019-08-20, SELL CREATE, 324000.00
# 2019-08-21, SELL EXECUTED, Price: 324500.00, Cost: 245500.00, Comm 0.00
# 2019-10-29, SELL CREATE, 300000.00
# 2019-10-30, SELL EXECUTED, Price: 302500.00, Cost: 245500.00, Comm 0.00
# 2019-11-07, SELL CREATE, 316500.00
# 2019-11-08, SELL EXECUTED, Price: 320500.00, Cost: 245500.00, Comm 0.00
# 2019-11-08, SELL CREATE, 323000.00
# 2019-11-11, SELL EXECUTED, Price: 323500.00, Cost: 245500.00, Comm 0.00
# 2019-11-11, SELL CREATE, 317000.00
# 2019-11-12, SELL EXECUTED, Price: 317500.00, Cost: 245500.00, Comm 0.00
# 2020-05-18, SELL CREATE, 354000.00
# 2020-05-19, SELL EXECUTED, Price: 363500.00, Cost: 245500.00, Comm 0.00
# 2020-05-19, SELL CREATE, 357000.00
# 2020-05-20, SELL EXECUTED, Price: 352500.00, Cost: 245500.00, Comm 0.00
# 2020-05-20, SELL CREATE, 362500.00
# 2020-05-21, SELL EXECUTED, Price: 367000.00, Cost: 245500.00, Comm 0.00
# 2020-05-21, SELL CREATE, 377500.00
# 2020-05-22, SELL EXECUTED, Price: 382000.00, Cost: 245500.00, Comm 0.00
# 2020-05-22, SELL CREATE, 377000.00
# 2020-05-25, SELL EXECUTED, Price: 380000.00, Cost: 245500.00, Comm 0.00
# 2021-05-12, SELL CREATE, 863000.00
# 2021-05-13, SELL EXECUTED, Price: 848000.00, Cost: 245500.00, Comm 0.00
# 2021-05-13, SELL CREATE, 850000.00
# 2021-05-14, SELL EXECUTED, Price: 852000.00, Cost: 245500.00, Comm 0.00
# 2021-05-14, SELL CREATE, 854000.00
# 2021-05-17, SELL EXECUTED, Price: 862000.00, Cost: 245500.00, Comm 0.00
# mdd : 40.54, cagr: 15.42
# 최종금액 :  20983500.0 원
# 수익률 :  109.835 %
#
#
# ['KR7051910008', 3813.0, 1249.0, 40.5432624521624, 15.424753046974942, 109.835]
# WARNING:tensorflow:Layer gru_57 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_58 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_59 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/80
# 72/72 [==============================] - 34s 408ms/step - loss: 0.3258 - accuracy: 0.0100 - val_loss: 0.3238 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 2/80
# 72/72 [==============================] - 29s 400ms/step - loss: 0.3055 - accuracy: 0.0103 - val_loss: 0.3006 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 3/80
# 72/72 [==============================] - 27s 377ms/step - loss: 0.2956 - accuracy: 0.0117 - val_loss: 0.2915 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 4/80
# 72/72 [==============================] - 28s 385ms/step - loss: 0.2848 - accuracy: 0.0117 - val_loss: 0.2808 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 5/80
# 72/72 [==============================] - 28s 392ms/step - loss: 0.2840 - accuracy: 0.0110 - val_loss: 0.2827 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 6/80
# 72/72 [==============================] - 29s 404ms/step - loss: 0.2775 - accuracy: 0.0112 - val_loss: 0.2805 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 7/80
# 72/72 [==============================] - 28s 387ms/step - loss: 0.2728 - accuracy: 0.0121 - val_loss: 0.3072 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 8/80
# 72/72 [==============================] - 28s 390ms/step - loss: 0.2721 - accuracy: 0.0114 - val_loss: 0.2824 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 9/80
# 72/72 [==============================] - 29s 400ms/step - loss: 0.2658 - accuracy: 0.0117 - val_loss: 0.2806 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 10/80
# 72/72 [==============================] - 28s 389ms/step - loss: 0.2601 - accuracy: 0.0121 - val_loss: 0.2844 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 11/80
# 72/72 [==============================] - 28s 388ms/step - loss: 0.2594 - accuracy: 0.0121 - val_loss: 0.2845 - val_accuracy: 0.0040 - lr: 0.0010
# Epoch 12/80
# 72/72 [==============================] - 28s 389ms/step - loss: 0.2474 - accuracy: 0.0124 - val_loss: 0.2844 - val_accuracy: 0.0040 - lr: 1.0000e-04
# Epoch 13/80
# 72/72 [==============================] - 28s 391ms/step - loss: 0.2443 - accuracy: 0.0126 - val_loss: 0.2867 - val_accuracy: 0.0040 - lr: 1.0000e-04
# Epoch 14/80
# 72/72 [==============================] - 28s 396ms/step - loss: 0.2422 - accuracy: 0.0133 - val_loss: 0.2854 - val_accuracy: 0.0040 - lr: 1.0000e-04
# Epoch 15/80
# 72/72 [==============================] - 29s 398ms/step - loss: 0.2441 - accuracy: 0.0135 - val_loss: 0.2853 - val_accuracy: 0.0040 - lr: 1.0000e-04
# Epoch 16/80
# 72/72 [==============================] - 29s 400ms/step - loss: 0.2418 - accuracy: 0.0138 - val_loss: 0.2848 - val_accuracy: 0.0040 - lr: 1.0000e-04
#
#  pred
#  0.0    1539
# -1.0     124
#  1.0      56
# dtype: int64 --------------------------------
# 2015-04-15, BUY CREATE, 47300.00
# 2015-04-16, BUY EXECUTED, Price: 46750.00, Cost: 9864250.00, Comm 0.00
# 2016-06-03, SELL CREATE, 46050.00
# 2016-06-07, SELL EXECUTED, Price: 46150.00, Cost: 46750.00, Comm 0.00
# 2016-06-07, SELL CREATE, 46150.00
# 2016-06-08, SELL EXECUTED, Price: 46350.00, Cost: 46750.00, Comm 0.00
# 2016-06-08, SELL CREATE, 46500.00
# 2016-06-09, SELL EXECUTED, Price: 46600.00, Cost: 46750.00, Comm 0.00
# 2016-10-17, SELL EXECUTED, Price: 41700.00, Cost: 46750.00, Comm 0.00
# 2016-10-17, SELL CREATE, 41650.00
# 2016-10-18, SELL EXECUTED, Price: 41500.00, Cost: 46750.00, Comm 0.00
# 2018-02-07, SELL CREATE, 34050.00
# 2018-02-08, SELL EXECUTED, Price: 34050.00, Cost: 46750.00, Comm 0.00
# 2018-02-08, SELL CREATE, 33900.00
# 2018-02-09, SELL EXECUTED, Price: 33250.00, Cost: 46750.00, Comm 0.00
# 2018-02-09, SELL CREATE, 33050.00
# 2018-02-12, SELL EXECUTED, Price: 33100.00, Cost: 46750.00, Comm 0.00
# 2018-02-12, SELL CREATE, 32850.00
# 2018-02-13, SELL EXECUTED, Price: 32850.00, Cost: 46750.00, Comm 0.00
# 2018-02-13, SELL CREATE, 32100.00
# 2018-02-14, SELL EXECUTED, Price: 32200.00, Cost: 46750.00, Comm 0.00
# 2018-06-15, SELL CREATE, 32200.00
# 2018-06-18, SELL EXECUTED, Price: 32400.00, Cost: 46750.00, Comm 0.00
# 2018-06-18, SELL CREATE, 32000.00
# 2018-06-19, SELL EXECUTED, Price: 31750.00, Cost: 46750.00, Comm 0.00
# 2018-06-19, SELL CREATE, 31700.00
# 2018-06-20, SELL EXECUTED, Price: 31700.00, Cost: 46750.00, Comm 0.00
# 2018-06-20, SELL CREATE, 31500.00
# 2018-06-21, SELL EXECUTED, Price: 31400.00, Cost: 46750.00, Comm 0.00
# 2018-06-21, SELL CREATE, 30800.00
# 2018-06-22, SELL EXECUTED, Price: 30450.00, Cost: 46750.00, Comm 0.00
# 2018-06-22, SELL CREATE, 31300.00
# 2018-06-25, SELL EXECUTED, Price: 31200.00, Cost: 46750.00, Comm 0.00
# 2018-06-25, SELL CREATE, 31450.00
# 2018-06-26, SELL EXECUTED, Price: 31250.00, Cost: 46750.00, Comm 0.00
# 2018-06-26, SELL CREATE, 31950.00
# 2018-06-27, SELL EXECUTED, Price: 31750.00, Cost: 46750.00, Comm 0.00
# 2018-06-27, SELL CREATE, 31000.00
# 2018-06-28, SELL EXECUTED, Price: 30700.00, Cost: 46750.00, Comm 0.00
# 2019-01-30, SELL CREATE, 36150.00
# 2019-01-31, SELL EXECUTED, Price: 36600.00, Cost: 46750.00, Comm 0.00
# 2019-01-31, SELL CREATE, 36350.00
# 2019-02-01, SELL EXECUTED, Price: 36350.00, Cost: 46750.00, Comm 0.00
# 2020-05-20, SELL CREATE, 30850.00
# 2020-05-21, SELL EXECUTED, Price: 31250.00, Cost: 46750.00, Comm 0.00
# 2020-05-21, SELL CREATE, 30600.00
# 2020-05-22, SELL EXECUTED, Price: 30650.00, Cost: 46750.00, Comm 0.00
# 2020-10-26, SELL CREATE, 47950.00
# 2020-10-27, SELL EXECUTED, Price: 50600.00, Cost: 46750.00, Comm 0.00
# 2020-10-27, SELL CREATE, 52900.00
# 2020-10-28, SELL EXECUTED, Price: 52600.00, Cost: 46750.00, Comm 0.00
# 2020-10-28, SELL CREATE, 53800.00
