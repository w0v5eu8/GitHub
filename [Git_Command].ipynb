# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #SSH Setting

# %%
# !mkdir -p ~/.ssh/
# !cp /content/drive/MyDrive/CodeData/GitHub_SSH/id_rsa ~/.ssh/
# !cp /content/drive/MyDrive/CodeData/GitHub_SSH/id_rsa.pub ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# cp: cannot stat '/content/drive/MyDrive/CodeData/GitHub_SSH/id_rsa': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/CodeData/GitHub_SSH/id_rsa.pub': No such file or directory
# chmod: cannot access '/root/.ssh/id_rsa': No such file or directory
# # github.com:22 SSH-2.0-babeld-57ca1323
# git@github.com: Permission denied (publickey).

# %%
cd /content/drive/MyDrive/Code/GitHub
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CodeData/GitHub'
# /content

# %% [markdown]
# # Git Command

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'
# Out:
# fatal: --local can only be used inside a git repository
# fatal: --local can only be used inside a git repository

# %%
# Push
# after source files update,

# !git add .
# !git commit -m 'Commit'
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git
