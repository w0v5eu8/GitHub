# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #SSH Setting

# %%
# !mkdir -p ~/.ssh/
# !cp /content/drive/MyDrive/CodeData/SSH/id_rsa ~/.ssh/
# !cp /content/drive/MyDrive/CodeData/SSH/id_rsa.pub ~/.ssh/

# %%
# !chmod 400 ~/.ssh/id_rsa

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-babeld-756a9a22
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %%
cd /content/drive/MyDrive/CodeData/GitHub
# Out:
# /content/drive/MyDrive/CodeData/GitHub

# %% [markdown]
# # Git Command

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# Push
# after source files update,

# !git add .
# !git commit -m 'Commit'
# !git push
# Out:
# [main 5355053] Commit
#  13 files changed, 242361 deletions(-)
#  delete mode 100644 ML_Data_anonymous.csv
#  delete mode 100644 ML_Data_car.csv
#  delete mode 100644 ML_Data_customer.csv
#  delete mode 100644 ML_Data_customer_pca.csv
#  delete mode 100644 ML_Data_dating.csv
#  delete mode 100644 ML_Data_example_cluster.csv
#  delete mode 100644 ML_Data_fraud.csv
#  delete mode 100644 ML_Data_insurance.csv
#  delete mode 100644 ML_Data_pima-indians-diabetes.csv
#  delete mode 100644 ML_Data_salary.csv
#  delete mode 100644 ML_Data_spam.csv
#  delete mode 100644 ML_Data_titanic.csv
#  delete mode 100644 ML_Data_wine.csv
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 215 bytes | 71.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:w0v5eu8/GitHub.git
#    273371b..5355053  main -> main

# %%
# !git pull
# Out:
# Already up to date.
