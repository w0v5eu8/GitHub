# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Git Setting (Cloning)

# %%
# cd /content/drive/MyDrive/CodeData

# %%
# !git clone 'https://w0v5eu8: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@github.com/w0v5eu8/GitHub.git' 'GitHub'

# %% [markdown]
# # Git Command

# %%
cd /content/drive/MyDrive/CodeData/GitHub
# Out:
# /content/drive/MyDrive/CodeData/GitHub

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# Push
# after source files update,
# !git add .
# !git commit -m 'Commit'
# !git push
# Out:
# [main 1746094] Commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 [Git_Command].ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.25 KiB | 256.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/w0v5eu8/GitHub.git
#    b9b2c2b..1746094  main -> main

# %%
# !git pull
# Out:
# Already up to date.

# %%
# if push is not working
# !git remote set-url origin https://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@github.com/w0v5eu8/Examples.git
